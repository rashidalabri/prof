# %%
# !pip install absl-py==2.0.0
# !pip install google.generativeai==0.1.0
# !pip install immutabledict==3.0.0
# !pip install openai==0.27.2

# %%
# !mkdir prof_final
# Out:
# mkdir: cannot create directory ‘prof_final’: File exists

# %%
# !cd prof_final; git clone https://github.com/rashidalabri/prof.git
# Out:
# Cloning into 'prof'...
# remote: Enumerating objects: 151, done.
# remote: Counting objects: 100% (151/151), done.
# remote: Compressing objects: 100% (139/139), done.
# remote: Total 151 (delta 10), reused 149 (delta 8), pack-reused 0 (from 0)
# Receiving objects: 100% (151/151), 4.62 MiB | 29.04 MiB/s, done.
# Resolving deltas: 100% (10/10), done.

# %%
# !cd /content/prof_final/prof/opro/optimization; python optimize_linear_regression_opro.py --optimizer="gpt-4o-mini" --w=15 --b=14 --num_reps=1 --openai_api_key=$OPENAI_API_KEY
# Out:
# result directory:
# /content/prof_final/prof/outputs/optimization-results/linear_regression-o-gpt-4o-mini-2024-12-17-23-58-05/
#
# ======== testing the optimizer server ===========
# optimizer test output: ['No.']
# Finished testing the optimizer server.
#
# ...
#
# Rep 0:
# value at (w_true, b_true): 47.037719254806696
# saving configs to
# /content/prof_final/prof/outputs/optimization-results/linear_regression-o-gpt-4o-mini-2024-12-17-23-58-05/configs.json
#
# ================ run optimization ==============
# initial points: [(18.0, 15.0), (16.0, 14.0), (15.0, 10.0), (10.0, 13.0), (17.0, 18.0)]
# initial values: [393751.20027700276, 42864.241410237184, 836.831780051746, 1086508.467779542, 192741.65104042264]
# saving results to
# /content/prof_final/prof/outputs/optimization-results/linear_regression-o-gpt-4o-mini-2024-12-17-23-58-05/results.json
#
# Step 0:
#
# ...
# meta_prompt:
# ...

# %%
# !cd /content/prof_final/prof/opro/optimization; python optimize_linear_regression_cot.py --optimizer="gpt-4o-mini" --w=15 --b=14 --num_reps=1 --openai_api_key=$OPENAI_API_KEY
# Out:
# result directory:
# /content/prof_final/prof/outputs/optimization-results/linear_regression-o-gpt-4o-mini-2024-12-18-00-00-56/
#
# ======== testing the optimizer server ===========
# optimizer test output: ['No.']
# Finished testing the optimizer server.
#
# ...
#
# Rep 0:
# value at (w_true, b_true): 47.037719254806696
# saving configs to
# /content/prof_final/prof/outputs/optimization-results/linear_regression-o-gpt-4o-mini-2024-12-18-00-00-56/configs.json
#
# ================ run optimization ==============
# initial points: [(18.0, 15.0), (16.0, 14.0), (15.0, 10.0), (10.0, 13.0), (17.0, 18.0)]
# initial values: [393751.20027700276, 42864.241410237184, 836.831780051746, 1086508.467779542, 192741.65104042264]
# saving results to
# /content/prof_final/prof/outputs/optimization-results/linear_regression-o-gpt-4o-mini-2024-12-18-00-00-56/results.json
#
# Step 0:
#
# ...
# meta_prompt:
# ...

# %%
# !cd /content/prof_final/prof/opro/optimization; python optimize_linear_regression_feedback.py --optimizer="gpt-4o-mini" --w=15 --b=14 --num_reps=1 --openai_api_key=$OPENAI_API_KEY
# Out:
# result directory:
# /content/prof_final/prof/outputs/optimization-results/linear_regression-o-gpt-4o-mini-2024-12-18-00-09-24/
#
# ======== testing the optimizer server ===========
# optimizer test output: ['No.']
# Finished testing the optimizer server.
#
# ...
#
# Rep 0:
# value at (w_true, b_true): 47.037719254806696
# saving configs to
# /content/prof_final/prof/outputs/optimization-results/linear_regression-o-gpt-4o-mini-2024-12-18-00-09-24/configs.json
#
# ================ run optimization ==============
# initial points: [(18.0, 15.0), (16.0, 14.0), (15.0, 10.0), (10.0, 13.0), (17.0, 18.0)]
# initial values: [393751.20027700276, 42864.241410237184, 836.831780051746, 1086508.467779542, 192741.65104042264]
# saving results to
# /content/prof_final/prof/outputs/optimization-results/linear_regression-o-gpt-4o-mini-2024-12-18-00-09-24/results.json
#
# Step 0:
#
# ...
# meta_prompt:
# ...

# %%
# !cd /content/prof_final/prof/opro/optimization; python optimize_linear_regression_prof.py --optimizer="gpt-4o-mini" --w=15 --b=14 --num_reps=1 --openai_api_key=$OPENAI_API_KEY
# Out:
# result directory:
# /content/prof_final/prof/outputs/optimization-results/linear_regression-o-gpt-4o-mini-2024-12-18-00-15-30/
#
# ======== testing the optimizer server ===========
# optimizer test output: ['No.']
# Finished testing the optimizer server.
#
# ...
#
# Rep 0:
# value at (w_true, b_true): 47.037719254806696
# saving configs to
# /content/prof_final/prof/outputs/optimization-results/linear_regression-o-gpt-4o-mini-2024-12-18-00-15-30/configs.json
#
# ================ run optimization ==============
# initial points: [(18.0, 15.0), (16.0, 14.0), (15.0, 10.0), (10.0, 13.0), (17.0, 18.0)]
# initial values: [393751.20027700276, 42864.241410237184, 836.831780051746, 1086508.467779542, 192741.65104042264]
# saving results to
# /content/prof_final/prof/outputs/optimization-results/linear_regression-o-gpt-4o-mini-2024-12-18-00-15-30/results.json
#
# Step 0:
#
# ...
# meta_prompt:
# ...
